# %%
import pandas as pd

# %% [markdown]
# # Text Normalization: Russian Language

# %%
# This challenge builds upon research out of Google: https://arxiv.org/pdf/1611.00068.pdf
# Essentially, text-to-speech systems must accuractely disambiguate text which can be spoken 
# different ways depending on context e.g. 12:00 am might be pronounced as "Twelve A M".
# Research suggests that traditional RNN approaches to this NLP problem are problematic.
# RNN embeddings convey semantic similarity through proximity in a vector space.
# Text Normalization fails to convey the correct meaning if one of few acceptable 
# interpretations is not used.

# %%
DATA_DIR = '../data/'
with open(DATA_DIR + 'ru_train.csv', 'r', encoding='UTF8') as infile:
    data = infile.readlines()

# %%
data = [x.strip() for x in data]

# %%
cols=data[0].replace('"', '').split(',')
data = data[1:]

# %%
sent_col = [x.split(',')[0] for x in data]
tok_col = [x.split(',')[1] for x in data]
data = [",".join(x.split(',')[2:]) for x in data]
data = [x.split('","') for x in data]
data = [[x.replace('"', '') for x in row] for row in data]

# %%
ru_df = pd.DataFrame(data, columns=cols[2:])

# %%
ru_df['sentence_id'] = sent_col
ru_df['token_id'] = tok_col

# %%
ru_df.head(10)
# Out:
#    class      before                                   after sentence_id  \
# 0  PLAIN          По                                      По           0
# 1  PLAIN   состоянию                               состоянию           0
# 2  PLAIN          на                                      на           0
# 3   DATE    1862 год  тысяча восемьсот шестьдесят второй год           0
# 4  PUNCT           .                                       .           0
# 5  PLAIN  Оснащались                              Оснащались           1
# 6  PLAIN     латными                                 латными           1
# 7  PLAIN  рукавицами                              рукавицами           1
# 8  PLAIN           и                                       и           1
# 9  PLAIN  сабатонами                              сабатонами           1
#
#   token_id
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# 5        0
# 6        1
# 7        2
# 8        3
# 9        4

# %%
print("Roughly {:.2f} percent of training tokens require normalization.".format(100 * ru_df.query("before!=after").shape[0] / len(ru_df)))
# Out:
# Roughly 12.51 percent of training tokens require normalization.

# %% [markdown]
# ## Simple Baselines: Dictionary Based Methods

# %%
# Just as in the Instacart Market Basket Analysis, we turn to simple dictionary based
# methods to establish a simple baseline to compare cost/benefit of the additional
# overhead of maintaining an ML system

# %%
trans_df = ru_df[['before', 'after']].query("before!=after").groupby('before', as_index=False)['after'].agg(lambda x:x.value_counts().index[0])

# %%
# As in the Instacart challenge, we select the value most frequently associated with the key

# %%
trans_dict = dict(zip(trans_df.before, trans_df.after))

# %%
trans_dict
# Out:
# {'': 'n a',
#  '#': 'решетка',
#  '$': 'доллар',
#  '$ 1,3 млн.': 'одну целую и три десятых миллиона долларов сэ ш а',
#  '$ 1,5 млн.': 'одну целую и пять десятых миллиона долларов сэ ш а',
#  '$ 1,7 млрд.': 'одной целой и семи десятых миллиарда долларов сэ ш а',
#  '$ 10 млн': 'десять миллионов долларов сэ ш а',
#  '$ 115 млн': 'ста пятнадцати миллионов долларов сэ ш а',
#  '$ 15,2 млн.': 'пятнадцати целых и двух десятых миллиона долларов сэ ш а',
#  '$ 16 млн.': 'шестнадцати миллионов долларов сэ ш а',
#  '$ 2,1 млрд.': 'двух целых и одной десятой миллиарда долларов сэ ш а',
#  '$ 20': 'двадцати долларов сэ ш а',
#  '$ 21,6 млн.': 'двадцати одной целой и шести десятых миллиона долларов сэ ш а',
#  '$ 220 млн.': 'двухсот двадцати миллионов долларов сэ ш а',
#  '$ 23 млрд': 'двадцати трех миллиардов долларов сэ ш а',
#  '$ 27 миллионов': 'двадцати семи миллионов долларов сэ ш а',
#  '$ 271 млн.': 'двухсот семидесяти одного миллиона долларов сэ ш а',
#  '$ 27млн.': 'двадцати семи миллионов долларов сэ ш а',
#  '$ 3': 'трех долларов сэ ш а',
#  '$ 370 млн.': 'трехсот семидесяти миллионов долларов сэ ш а',
#  '$ 5 млн': 'пяти миллионов долларов сэ ш а',
#  '$ 50 млн': 'пятидесяти миллионов долларов сэ ш а',
#  '$ 500 млрд': 'пятьсот миллиардов долларов сэ ш а',
#  '$ 50000': 'пятидесяти тысяч долларов сэ ш а',
#  '$ 510 млн.': 'пятисот десяти миллионов долларов сэ ш а',
#  '$ 605 млн.': 'шестисот пяти миллионов долларов сэ ш а',
#  '$ 66 млн.': 'шестидесяти шести миллионов долларов сэ ш а',
#  '$ 70 млрд': 'семидесяти миллиардов долларов сэ ш а',
#  '$ 85,3': 'восьмидесяти пяти долларов сэ ш а и тридцати центов',
#  '$ 9,825 млн.': 'девяти целых и восьмисот двадцати пяти тысячных миллиона долларов сэ ш а',
#  '$0,99': 'девяносто девять центов',
#  '$1': 'один доллар сэ ш а',
#  '$1 000 000': 'миллион долларов сэ ш а',
#  '$1 390 530': 'миллион триста девяносто тысяч пятьсот тридцать долларов сэ ш а',
#  '$1 843 296': 'миллион восемьсот сорок три тысячи двести девяносто шесть долларов сэ ш а',
#  '$1 млрд.': 'одного миллиарда долларов сэ ш а',
#  '$1 трлн': 'одном триллионе долларов сэ ш а',
#  '$1,1 млн': 'одной целой и одной десятой миллиона долларов сэ ш а',
#  '$1,10': 'один доллар сэ ш а и десять центов',
#  '$1,2 млрд': 'одну целую и две десятых миллиарда долларов сэ ш а',
#  '$1,25 млрд': 'одна целая и двадцать пять сотых миллиарда долларов сэ ш а',
#  '$1,27 млрд.': 'одну целую и двадцать семь сотых миллиарда долларов сэ ш а',
#  '$1,3 млрд': 'одну целую и три десятых миллиарда долларов сэ ш а',
#  '$1,4 млрд': 'одной целой и четырех десятых миллиарда долларов сэ ш а',
#  '$1,4 млрд.': 'одну целую и четыре десятых миллиарда долларов сэ ш а',
#  '$1,405 млрд.': 'одной целой и четырехсот пяти тысячных миллиарда долларов сэ ш а',
#  '$1,5 млн': 'одна целая и пять десятых миллиона долларов сэ ш а',
#  '$1,5 млн.': 'одну целую и пять десятых миллиона долларов сэ ш а',
#  '$1,5 млрд.': 'одна целая и пять десятых миллиарда долларов сэ ш а',
#  '$1,6 млрд.': 'одной целой и шести десятых миллиарда долларов сэ ш а',
#  '$1,7 млн.': 'одну целую и семь десятых миллиона долларов сэ ш а',
#  '$1,7 млрд': 'одну целую и семь десятых миллиарда долларов сэ ш а',
#  '$1,75 млрд.': 'одну целую и семьдесят пять сотых миллиарда долларов сэ ш а',
#  '$1,9 млрд.': 'одной целой и девяти десятых миллиарда долларов сэ ш а',
#  '$10': 'десять долларов сэ ш а',
#  '$10 000': 'десятью тысячами долларами сэ ш а',
#  '$10 миллионов': 'десять миллионов долларов сэ ш а',
#  '$10 млн.': 'десяти миллионов долларов сэ ш а',
#  '$10 млрд.': 'десяти миллиардов долларов сэ ш а',
#  '$100': 'сто долларов сэ ш а',
#  '$100 000': 'сто тысяч долларов сэ ш а',
#  '$100 млн': 'сто миллионов долларов сэ ш а',
#  '$100 млн.': 'ста миллионов долларов сэ ш а',
#  '$100 млрд.': 'ста миллиардов долларов сэ ш а',
#  '$100 тыс.': 'сто тысяч долларов сэ ш а',
#  '$10000': 'десять тысяч долларов сэ ш а',
#  '$102': 'сто два доллара сэ ш а',
#  '$105 000': 'сто пять тысяч долларов сэ ш а',
#  '$11,3 млн.': 'одиннадцать целых и три десятых миллиона долларов сэ ш а',
#  '$11,4 млрд.': 'одиннадцать целых и четыре десятых миллиарда долларов сэ ш а',
#  '$11,9 млрд.': 'одиннадцать целых и девять десятых миллиарда долларов сэ ш а',
#  '$110': 'сто десять долларов сэ ш а',
#  '$112,5 млн': 'сто двенадцать целых и пять десятых миллиона долларов сэ ш а',
#  '$113000': 'сто тринадцать тысяч долларов сэ ш а',
#  '$114,015': 'сто четырнадцать целых и пятнадцать тысячных доллара сэ ш а',
#  '$116,4 млн.': 'сто шестнадцать целых и четыре десятых миллиона долларов сэ ш а',
#  '$12 млн.': 'двенадцатью миллионами долларов сэ ш а',
#  '$12,3 млрд.': 'двенадцать целых и три десятых миллиарда долларов сэ ш а',
#  '$120': 'ста двадцати долларов сэ ш а',
#  '$125 000': 'сто двадцать пять тысяч долларов сэ ш а',
#  '$13': 'тринадцати долларов сэ ш а',
#  '$13 млн': 'тринадцать миллионов долларов сэ ш а',
#  '$135 млн': 'сто тридцать пять миллионов долларов сэ ш а',
#  '$1397,4 млрд.': 'тысяча триста девяносто семь целых и четыре десятых миллиарда долларов сэ ш а',
#  '$14 млн': 'четырнадцати миллионов долларов сэ ш а',
#  '$14 млн.': 'четырнадцать миллионов долларов сэ ш а',
#  '$14 тыс': 'четырнадцать тысяч долларов сэ ш а',
#  '$145 млн': 'ста сорока пяти миллионов долларов сэ ш а',
#  '$15': 'пятнадцати долларов сэ ш а',
#  '$15 000': 'пятнадцать тысяч долларов сэ ш а',
#  '$15 млн.': 'пятнадцать миллионов долларов сэ ш а',
#  '$15,33 трлн': 'пятнадцати целых и тридцати трех сотых триллиона долларов сэ ш а',
#  '$150': 'сто пятьдесят долларов сэ ш а',
#  '$154,8 млн': 'сто пятьдесят четыре целых и восемь десятых миллиона долларов сэ ш а',
#  '$15514': 'пятнадцать тысяч пятьсот четырнадцать долларов сэ ш а',
#  '$16': 'шестнадцати долларов сэ ш а',
#  '$16 000': 'шестнадцати тысяч долларов сэ ш а',
#  '$1618': 'тысячи шестисот восемнадцати долларов сэ ш а',
#  '$163': 'сто шестьдесят три доллара сэ ш а',
#  '$16670': 'шестнадцать тысяч шестьсот семьдесят долларов сэ ш а',
#  '$16969': 'шестнадцать тысяч девятьсот шестьдесят девять долларов сэ ш а',
#  '$17 млрд.': 'семнадцати миллиардов долларов сэ ш а',
#  '$17,850': 'семнадцать целых и восемьсот пятьдесят тысячных доллара сэ ш а',
#  '$170 млн': 'ста семидесяти миллионах долларов сэ ш а',
#  '$172,8 млн': 'сто семьдесят две целых и восемь десятых миллиона долларов сэ ш а',
#  '$17489': 'семнадцать тысяч четыреста восемьдесят девять долларов сэ ш а',
#  '$17842': 'семнадцать тысяч восемьсот сорок два доллара сэ ш а',
#  '$179,5': 'сто семьдесят девять долларов сэ ш а и пятьдесят центов',
#  '$18': 'восемнадцать долларов сэ ш а',
#  '$18 млн.': 'восемнадцать миллионов долларов сэ ш а',
#  '$189,500': 'сто восемьдесят девять целых и пятьсот тысячных доллара сэ ш а',
#  '$19 млн.': 'девятнадцати миллионов долларов сэ ш а',
#  '$190 миллионов': 'ста девяноста миллионам долларов сэ ш а',
#  '$2': 'два доллара сэ ш а',
#  '$2 325 млн': 'две тысячи триста двадцать пять миллионов долларов сэ ш а',
#  '$2 400 000': 'два миллиона четыреста тысяч долларов сэ ш а',
#  '$2,0 млрд.': 'два миллиарда долларов сэ ш а',
#  '$2,1 млрд.': 'две целых и одну десятую миллиарда долларов сэ ш а',
#  '$2,3 млрд.': 'две целых и три десятых миллиарда долларов сэ ш а',
#  '$2,5 млрд': 'две целых и пять десятых миллиарда долларов сэ ш а',
#  '$2,63 млн.': 'две целых и шестьдесят три сотых миллиона долларов сэ ш а',
#  '$2,660': 'две целых и шестьсот шестьдесят тысячных доллара сэ ш а',
#  '$2,75': 'два доллара сэ ш а и семьдесят пять центов',
#  '$2,9 млрд.': 'две целых и девять десятых миллиарда долларов сэ ш а',
#  '$2,999': 'две целых и девятьсот девяносто девять тысячных доллара сэ ш а',
#  '$20': 'двадцать долларов сэ ш а',
#  '$20 миллионов': 'двадцати миллионов долларов сэ ш а',
#  '$20 млн': 'двадцати миллионов долларов сэ ш а',
#  '$20 млн.': 'двадцать миллионов долларов сэ ш а',
#  '$200': 'двести долларов сэ ш а',
#  '$200 млн': 'двухсот миллионов долларов сэ ш а',
#  '$200 млн.': 'двести миллионов долларов сэ ш а',
#  '$200m': 'двести миллионов долларов сэ ш а',
#  '$20m': 'двадцать миллионов долларов сэ ш а',
#  '$21,580': 'двадцать одна целая и пятьсот восемьдесят тысячных доллара сэ ш а',
#  '$217 млн.': 'двести семнадцать миллионов долларов сэ ш а',
#  '$22': 'двадцать два доллара сэ ш а',
#  '$22 млрд.': 'двадцать два миллиарда долларов сэ ш а',
#  '$22,5 млрд.': 'двадцать две целых и пять десятых миллиарда долларов сэ ш а',
#  '$225 млн.': 'двести двадцать пять миллионов долларов сэ ш а',
#  '$23,5 млрд.': 'двадцать три целых и пять десятых миллиарда долларов сэ ш а',
#  '$23,7 млрд': 'двадцать три целых и семь десятых миллиарда долларов сэ ш а',
#  '$233 миллиона': 'двести тридцать три миллиона долларов сэ ш а',
#  '$235 000': 'двухсот тридцати пяти тысяч долларов сэ ш а',
#  '$24,1 млрд': 'двадцать четыре целых и одна десятая миллиарда долларов сэ ш а',
#  '$24000': 'двадцать четыре тысячи долларов сэ ш а',
#  '$244 миллиона': 'двести сорок четыре миллиона долларов сэ ш а',
#  '$246 млрд': 'двести сорок шесть миллиардов долларов сэ ш а',
#  '$249': 'двести сорок девять долларов сэ ш а',
#  '$25': 'двадцати пяти долларов сэ ш а',
#  '$25 млн': 'двадцати пяти миллионов долларов сэ ш а',
#  '$25 трлн.': 'двадцати пяти триллионов долларов сэ ш а',
#  '$25,990': 'двадцать пять целых и девятьсот девяносто тысячных доллара сэ ш а',
#  '$250': 'двести пятьдесят долларов сэ ш а',
#  '$250 млн': 'двести пятьдесят миллионов долларов сэ ш а',
#  '$250 млн.': 'двухсот пятидесяти миллионов долларов сэ ш а',
#  '$250 тысяч': 'двести пятьдесят тысяч долларов сэ ш а',
#  '$250m': 'двести пятьдесят миллионов долларов сэ ш а',
#  '$26 млрд': 'двадцать шесть миллиардов долларов сэ ш а',
#  '$265 млн.': 'двести шестьдесят пять миллионов долларов сэ ш а',
#  '$27,07 млрд': 'двадцать семь целых и семь сотых миллиарда долларов сэ ш а',
#  '$27,93 млрд.': 'двадцать семь целых и девяносто три сотых миллиарда долларов сэ ш а',
#  '$274 млн.': 'двухсот семидесяти четырех миллионов долларов сэ ш а',
#  '$28': 'двадцать восемь долларов сэ ш а',
#  '$28 000': 'двадцати восьми тысяч долларов сэ ш а',
#  '$285,5 млн': 'двести восемьдесят пять целых и пять десятых миллиона долларов сэ ш а',
#  '$29 млн.': 'двадцати девяти миллионах долларов сэ ш а',
#  '$29,7 млрд': 'двадцать девять целых и семь десятых миллиарда долларов сэ ш а',
#  '$299': 'двести девяносто девять долларов сэ ш а',
#  '$2bn': 'два миллиарда долларов сэ ш а',
#  '$3': 'три доллара сэ ш а',
#  '$3 миллионов': 'трех миллионов долларов сэ ш а',
#  '$3 млн.': 'трех миллионов долларов сэ ш а',
#  '$3 млрд': 'трех миллиардов долларов сэ ш а',
#  '$3 млрд.': 'три миллиарда долларов сэ ш а',
#  '$3,19 млрд.': 'три целых и девятнадцать сотых миллиарда долларов сэ ш а',
#  '$3,2 миллиарда': 'три целых и две десятых миллиарда долларов сэ ш а',
#  '$3,2 млрд': 'трех целых и двух десятых миллиарда долларов сэ ш а',
#  '$3,9 млрд.': 'три целых и девять десятых миллиарда долларов сэ ш а',
#  '$30': 'тридцать долларов сэ ш а',
#  '$30 миллионов': 'тридцати миллионов долларов сэ ш а',
#  '$30 млн.': 'тридцати миллионах долларов сэ ш а',
#  '$30 млрд.': 'тридцати миллиардов долларов сэ ш а',
#  '$30,15 миллиона': 'тридцать целых и пятнадцать сотых миллиона долларов сэ ш а',
#  '$300': 'триста долларов сэ ш а',
#  '$300 000': 'трехсот тысяч долларов сэ ш а',
#  '$300 млн.': 'трехсот миллионов долларов сэ ш а',
#  '$3000': 'три тысячи долларов сэ ш а',
#  '$3005': 'три тысячи пять долларов сэ ш а',
#  '$3040': 'три тысячи сорок долларов сэ ш а',
#  '$32': 'тридцать два доллара сэ ш а',
#  '$32 000': 'тридцать две тысячи долларов сэ ш а',
#  '$320': 'триста двадцать долларов сэ ш а',
#  '$325': 'трехсот двадцати пяти долларов сэ ш а',
#  '$33,3 млн.': 'тридцать три целых и три десятых миллиона долларов сэ ш а',
#  '$33,7 млрд.': 'тридцать три целых и семь десятых миллиарда долларов сэ ш а',
#  '$338,9 млн.': 'триста тридцать восемь целых и девять десятых миллиона долларов сэ ш а',
#  '$34 000': 'тридцать четыре тысячи долларов сэ ш а',
#  '$34 млрд': 'тридцати четырех миллиардов долларов сэ ш а',
#  '$35': 'тридцать пять долларов сэ ш а',
#  '$35 млн': 'тридцати пяти миллионах долларов сэ ш а',
#  '$350 млн': 'трехсот пятидесяти миллионов долларов сэ ш а',
#  '$358,5 млрд.': 'триста пятьдесят восемь целых и пять десятых миллиарда долларов сэ ш а',
#  '$38': 'тридцать восемь долларов сэ ш а',
#  '$38 млн.': 'тридцати восьми миллионах долларов сэ ш а',
#  '$381,7 млн.': 'трехсот восьмидесяти одной целой и семи десятых миллиона долларов сэ ш а',
#  '$3985 млн.': 'три тысячи девятьсот восемьдесят пять миллионов долларов сэ ш а',
#  '$4': 'четыре доллара сэ ш а',
#  '$4 миллиарда': 'четыре миллиарда долларов сэ ш а',
#  '$4 млн': 'четырех миллионов долларов сэ ш а',
#  '$4 млрд.': 'четыре миллиарда долларов сэ ш а',
#  '$4,23 млн': 'четырех целых и двадцати трех сотых миллиона долларов сэ ш а',
#  '$4,5 млрд.': 'четыре целых и пять десятых миллиарда долларов сэ ш а',
#  '$4,55 млрд': 'четыре целых и пятьдесят пять сотых миллиарда долларов сэ ш а',
#  '$4,600': 'четыре целых и шестьсот тысячных доллара сэ ш а',
#  '$4,7 млрд.': 'четырех целых и семи десятых миллиарда долларов сэ ш а',
#  '$40': 'сорока долларов сэ ш а',
#  '$40 млн': 'сорок миллионов долларов сэ ш а',
#  '$40 млн.': 'сорок миллионов долларов сэ ш а',
#  '$400 000': 'четыреста тысяч долларов сэ ш а',
#  '$400 млн': 'четырехсот миллионов долларов сэ ш а',
#  '$400 млн.': 'четырехсот миллионов долларов сэ ш а',
#  '$4000': 'четырех тысяч долларов сэ ш а',
#  '$40399': 'сорок тысяч триста девяносто девять долларов сэ ш а',
#  '$41009': 'сорок одну тысячу девять долларов сэ ш а',
#  '$419,098': 'четырехсот девятнадцати целых и девяноста восьми тысячных доллара сэ ш а',
#  '$420 млн': 'четырехсот двадцати миллионов долларов сэ ш а',
#  '$429 млн': 'четыреста двадцать девять миллионов долларов сэ ш а',
#  '$43': 'сорока трех долларов сэ ш а',
#  '$435 000': 'четыреста тридцать пять тысяч долларов сэ ш а',
#  '$44,8 млрд': 'сорок четыре целых и восемь десятых миллиарда долларов сэ ш а',
#  '$45': 'сорока пяти долларов сэ ш а',
#  '$45 миллионов': 'сорок пять миллионов долларов сэ ш а',
#  '$45 млн': 'сорок пять миллионов долларов сэ ш а',
#  '$452 млрд.': 'четыреста пятьдесят два миллиарда долларов сэ ш а',
#  '$46,8 млрд.': 'сорок шесть целых и восемь десятых миллиарда долларов сэ ш а',
#  '$464,273 млрд': 'четыреста шестьдесят четыре целых и двести семьдесят три тысячных миллиарда долларов сэ ш а',
#  '$48': 'сорок восемь долларов сэ ш а',
#  '$48 млрд.': 'сорока восьми миллиардов долларов сэ ш а',
#  '$48,5 млрд.': 'сорок восемь целых и пять десятых миллиарда долларов сэ ш а',
#  '$497,3 млн': 'четыреста девяносто семь целых и три десятых миллиона долларов сэ ш а',
#  '$499': 'четыреста девяносто девять долларов сэ ш а',
#  '$5': 'пять долларов сэ ш а',
#  '$5 млн': 'пять миллионов долларов сэ ш а',
#  '$5 млн.': 'пяти миллионах долларов сэ ш а',
#  '$5 млрд.': 'пяти миллиардов долларов сэ ш а',
#  '$5,1 млрд': 'пять целых и одна десятая миллиарда долларов сэ ш а',
#  '$50': 'пятьдесят долларов сэ ш а',
#  '$50 000': 'пятьдесят тысяч долларов сэ ш а',
#  '$500': 'пятьсот долларов сэ ш а',
#  '$500 млн': 'пятисот миллионов долларов сэ ш а',
#  '$500 млн.': 'пятьсот миллионов долларов сэ ш а',
#  '$500 тысяч': 'пятьсот тысяч долларов сэ ш а',
#  '$50000': 'пятьдесят тысяч долларов сэ ш а',
#  '$501': 'пятьсот один доллар сэ ш а',
#  '$50m': 'пятьдесят миллионов долларов сэ ш а',
#  '$51,3 млн.': 'пятьдесят одна целая и три десятых миллиона долларов сэ ш а',
#  '$51973': 'пятьдесят одну тысячу девятьсот семьдесят три доллара сэ ш а',
#  '$520 млн': 'пятисот двадцати миллионов долларов сэ ш а',
#  '$54': 'пятидесяти четырех долларов сэ ш а',
#  '$55': 'пятьдесят пять долларов сэ ш а',
#  '$56 000': 'пятьдесят шесть тысяч долларов сэ ш а',
#  '$575': 'пятьсот семьдесят пять долларов сэ ш а',
#  '$598 млн.': 'пятисот девяноста восьми миллионов долларов сэ ш а',
#  '$6': 'шесть долларов сэ ш а',
#  '$6 млн.': 'шесть миллионов долларов сэ ш а',
#  '$6 млрд.': 'шести миллиардов долларов сэ ш а',
#  '$6,4 млн.': 'шесть целых и четыре десятых миллиона долларов сэ ш а',
#  '$60': 'шестьдесят долларов сэ ш а',
#  '$60 млн.': 'шестидесяти миллионах долларов сэ ш а',
#  '$600 млн.': 'шестисот миллионов долларов сэ ш а',
#  '$60000': 'шестидесяти тысяч долларов сэ ш а',
#  '$62,5 млрд': 'шестьдесят две целых и пять десятых миллиарда долларов сэ ш а',
#  '$634 млрд.': 'шестьсот тридцать четыре миллиарда долларов сэ ш а',
#  '$64': 'шестьдесят четыре доллара сэ ш а',
#  '$650': 'шестьсот пятьдесят долларов сэ ш а',
#  '$663 млн': 'шестьсот шестьдесят три миллиона долларов сэ ш а',
#  '$665 тыс.': 'шестьсот шестьдесят пять тысяч долларов сэ ш а',
#  '$66bn': 'шестьдесят шесть миллиардов долларов сэ ш а',
#  '$7': 'семь долларов сэ ш а',
#  '$7 млрд': 'семь миллиардов долларов сэ ш а',
#  '$7,15 миллиона': 'семи целых и пятнадцати сотых миллиона долларов сэ ш а',
#  '$70 млн': 'семьдесят миллионов долларов сэ ш а',
#  '$70 млн.': 'семидесяти миллионов долларов сэ ш а',
#  '$70 млрд.': 'семидесяти миллиардов долларов сэ ш а',
#  '$71 млн': 'семьдесят один миллион долларов сэ ш а',
#  '$74 млрд': 'семьдесят четыре миллиарда долларов сэ ш а',
#  '$750 млн.': 'семьсот пятьдесят миллионов долларов сэ ш а',
#  '$784 млн.': 'семисот восьмидесяти четырех миллионов долларов сэ ш а',
#  '$8': 'восемь долларов сэ ш а',
#  '$8 миллионов': 'восемь миллионов долларов сэ ш а',
#  '$8 тысяч': 'восемь тысяч долларов сэ ш а',
#  '$8,2 млрд': 'восемь целых и две десятых миллиарда долларов сэ ш а',
#  '$80 млн.': 'восьмидесяти миллионов долларов сэ ш а',
#  '$800': 'восемьсот долларов сэ ш а',
#  '$818k': 'восемьсот восемнадцать тысяч долларов сэ ш а',
#  '$82,500': 'восемьдесят две целых и пятьсот тысячных доллара сэ ш а',
#  '$830 млн': 'восемьсот тридцать миллионов долларов сэ ш а',
#  '$85 млн.': 'восьмидесяти пяти миллионов долларов сэ ш а',
#  '$85,5': 'восьмидесяти пяти долларов сэ ш а и пятидесяти центов',
#  '$850 млн': 'восемьсот пятьдесят миллионов долларов сэ ш а',
#  '$86,4 млрд': 'восьмидесяти шести целых и четырех десятых миллиарда долларов сэ ш а',
#  '$87': 'восемьдесят семь долларов сэ ш а',
#  '$8900': 'восьми тысяч девятисот долларов сэ ш а',
#  '$9': 'девять долларов сэ ш а',
#  '$9 млн.': 'девяти миллионов долларов сэ ш а',
#  '$9,5 млн': 'девять целых и пять десятых миллиона долларов сэ ш а',
#  '$9,999': 'девять целых и девятьсот девяносто девять тысячных доллара сэ ш а',
#  '$90 млн': 'девяноста миллионов долларов сэ ш а',
#  '$90 млн.': 'девяноста миллионов долларов сэ ш а',
#  '$90 млрд.': 'девяносто миллиардов долларов сэ ш а',
#  '$90,9 млн.': 'девяносто целых и девять десятых миллиона долларов сэ ш а',
#  '$900 млн': 'девятисот миллионов долларов сэ ш а',
#  '$905 млн': 'девятьсот пять миллионов долларов сэ ш а',
#  '$94,2 миллионов': 'девяносто четыре целых и две десятых миллиона долларов сэ ш а',
#  '$94,5 млн': 'девяноста четырех целых и пяти десятых миллиона долларов сэ ш а',
#  '$9450': 'девять тысяч четыреста пятьдесят долларов сэ ш а',
#  '$9549': 'девять тысяч пятьсот сорок девять долларов сэ ш а',
#  '$96 млн': 'девяноста шести миллионов долларов сэ ш а',
#  '%': 'процент',
#  '&': 'и',
#  '(03)-79': 'ноль три sil семьдесят девять',
#  '(1)2': 'один sil два',
#  '(101955) 1999 RQ': 'сто один девятьсот пятьдесят пять sil девятнадцать девяносто девять sil r q',
#  '(1038) 40': 'десять тридцать восемь sil сорок',
#  '(12) 25': 'двенадцать sil двадцать пять',
#  '(15) 40': 'пятнадцать sil сорок',
#  '(1876)76': 'восемнадцать семьдесят шесть sil семьдесят шесть',
#  '(1895) 660': 'восемнадцать девяносто пять sil шестьсот шестьдесят',
#  '(1944)11': 'девятнадцать сорок четыре sil одиннадцать',
#  '(1944)15': 'девятнадцать сорок четыре sil пятнадцать',
#  '(1946) 40': 'девятнадцать сорок шесть sil сорок',
#  '(1947)2': 'девятнадцать сорок семь sil два',
#  '(1949)6': 'девятнадцать сорок девять sil шесть',
#  '(1953)1937': 'девятнадцать пятьдесят три sil девятнадцать тридцать семь',
#  '(1958)19': 'девятнадцать пятьдесят восемь sil девятнадцать',
#  '(1958)37': 'девятнадцать пятьдесят восемь sil тридцать семь',
#  '(1965)2': 'девятнадцать шестьдесят пять sil два',
#  '(1969)700': 'девятнадцать шестьдесят девять sil семьсот',
#  '(1971)60 595': 'девятнадцать семьдесят один sil шестьдесят sil пятьсот девяносто пять',
#  '(1977) 236': 'девятнадцать семьдесят семь sil двести тридцать шесть',
#  '(1979)4': 'девятнадцать семьдесят девять sil четыре',
#  '(1980) 22': 'девятнадцать восемьдесят sil двадцать два',
#  '(1989)-3': 'девятнадцать восемьдесят девять sil три',
#  '(1993) 5': 'девятнадцать девяносто три sil пять',
#  '(1997)008': 'девятнадцать девяносто семь sil ноль ноль восемь',
#  '(1998)15': 'девятнадцать девяносто восемь sil пятнадцать',
#  '(2002)200': 'две тысячи два sil двести',
#  '(2005)775 495': 'две тысячи пять sil семьсот семьдесят пять sil четыреста девяносто пять',
#  '(2006) 7': 'две тысячи шесть sil семь',
#  '(2007) 3': 'две тысячи семь sil три',
#  '(2011) 54': 'двадцать одиннадцать sil пятьдесят четыре',
#  '(2013) 2': 'двадцать тринадцать sil два',
#  '(225088) 2007 OR': 'два два пять ноль восемь восемь sil две тысячи семь sil o r',
#  '(3) 15': 'три sil пятнадцать',
#  '(3) 4': 'три sil четыре',
#  '(47171) 1999 TC': 'четыреста семьдесят один семьдесят один sil девятнадцать девяносто девять sil t c',
#  '(495) 625-5146': 'четыреста девяносто пять sil шестьсот двадцать пять sil пятьдесят один сорок шесть',
#  '(5)7': 'пять sil семь',
#  '(53236) 013': 'пятьсот тридцать два тридцать шесть sil ноль тринадцать',
#  '(8)10': 'восемь sil десять',
#  '(80)90098-9': 'восемьдесят sil девятьсот девяносто восемь sil девять',
#  '(812) 436-34-48': 'восемьсот двенадцать sil четыреста тридцать шесть sil тридцать четыре sil сорок восемь',
#  '(812) 768-21-37': 'восемьсот двенадцать sil семьсот шестьдесят восемь sil двадцать один sil тридцать семь',
#  '(82)90057-7': 'восемьдесят два sil девятьсот пятьдесят семь sil семь',
#  '(8793) 333': 'восемьдесят семь девяносто три sil триста тридцать три',
#  '(93) 38': 'девяносто три sil тридцать восемь',
#  '(971) 1921 LF': 'девятьсот семьдесят один sil девятнадцать двадцать один sil l f',
#  '+': 'плюс',
#  '-': 'до',
#  '- ': 'до',
#  '- 100': 'сотом',
#  '- 1482': 'тысяча четыреста восемьдесят втором',
#  '- 1775': 'тысяча семьсот семьдесят пятом',
#  '- 1795': 'тысяча семьсот девяносто пятом',
#  '- 1855': 'тысяча восемьсот пятьдесят пятом',
#  '- 1908': 'тысяча девятьсот восьмом',
#  '- 1913': 'тысяча девятьсот тринадцатом',
#  '- 1928': 'тысяча девятьсот двадцать восьмом',
#  '- 1941': 'тысяча девятьсот сорок первом',
#  '- 1944': 'тысяча девятьсот сорок четвертом',
#  '- 1945': 'тысяча девятьсот сорок пятого',
#  '- 1947': 'тысяча девятьсот сорок седьмом',
#  '- 1948': 'тысяча девятьсот сорок восьмом',
#  '- 1970': 'тысяча девятьсот семидесятом',
#  '- 1978': 'тысяча девятьсот семьдесят восьмом',
#  '- 1981': 'тысяча девятьсот восемьдесят первом',
#  '- 1985': 'тысяча девятьсот восемьдесят пятом',
#  '- 1987': 'тысяча девятьсот восемьдесят седьмом',
#  '- 1991': 'тысяча девятьсот девяносто первом',
#  '- 1993': 'тысяча девятьсот девяносто третьем',
#  '- 1996': 'тысяча девятьсот девяносто шестом',
#  '- 1999': 'тысяча девятьсот девяносто девятом',
#  '- 2000': 'двух тысячном',
#  '- 2001': 'две тысячи первом',
#  '- 2004': 'две тысячи четвертом',
#  '- 2005': 'две тысячи пятом',
#  '- 2007': 'две тысячи седьмом',
#  '- 2008': 'две тысячи восьмом',
#  '- 2014': 'две тысячи четырнадцатом',
#  '- 2015': 'две тысячи пятнадцатом',
#  '- 34': 'тридцать четвертом',
#  '- 88': 'восемьдесят восьмом',
#  '-0': 'минус ноль',
#  '-0,002': 'минус ноль целых и две тысячных',
#  '-0,01 %': 'минус ноль целых и одну сотую процента',
#  '-0,04m': 'минус ноль целых и четыре сотых миллиона',
#  '-0,15': 'минус ноль целых и пятнадцать сотых',
#  '-0,15 мг': 'минус ноль целых и пятнадцать сотых миллиграмма',
#  '-0,15 млн': 'минус ноль целых и пятнадцать сотых миллиона',
#  '-0,2': 'минус ноль целых и две десятых',
#  '-0,2 %': 'минус ноль целых и две десятых процента',
#  '-0,2 мг': 'минус ноль целых и две десятых миллиграмма',
#  '-0,3 мм.': 'минус ноль целых и три десятых миллиметра',
#  '-0,3%': 'минус ноль целых и три десятых процента',
#  '-0,392': 'минус ноль целых и триста девяносто две тысячных',
#  '-0,4 м.': 'минус ноль целых и четыре десятых метра',
#  '-0,4 метра.': 'минус ноль целых и четыре десятых метра',
#  '-0,41': 'минус ноль целых и сорок одна сотая',
#  '-0,46 %': 'минус ноль целых и сорок шесть сотых процента',
#  '-0,49 грамм': 'минус ноль целых и сорок девять сотых грамм',
#  '-0,5': 'минус ноль целых и пять десятых',
#  '-0,6 м': 'минус ноль целых и шесть десятых метра',
#  '-0,6 мм': 'минус ноль целых и шесть десятых миллиметра',
#  '-0,6 см.': 'минус ноль целых и шесть десятых сантиметра',
#  '-0,64': 'минус ноль целых и шестьдесят четыре сотых',
#  '-0,75 мм': 'минус ноль целых и семьдесят пять сотых миллиметра',
#  '-0,78 МПа.': 'минус ноль целых и семьдесят восемь сотых мегапаскаля',
#  '-0,8': 'минус нулем целыми и восьмью десятыми',
#  '-0,8 км.': 'минус ноль целых и восемь десятых километра',
#  '-0,8 метра.': 'минус ноль целых и восемь десятых метра',
#  '-0,81': 'минус ноль целых и восемьдесят одна сотая',
#  '-0,84': 'минус ноль целых и восемьдесят четыре сотых',
#  '-0,9': 'минус ноль целых и девять десятых',
#  '-0,92 кг': 'минус ноль целых и девяносто две сотых килограмма',
#  '-0А.': 'минус ноль ампер',
#  '-1': 'минус один',
#  '-1 м': 'минус один метр',
#  '-1 с': 'минус одна секунда',
#  '-1,01': 'минус одна целая и одна сотая',
#  '-1,1': 'минус одна целая и одна десятая',
#  '-1,2 %': 'минус одна целая и две десятых процента',
#  '-1,3': 'минус одна целая и три десятых',
#  '-1,3 %': 'минус одна целая и три десятых процента',
#  '-1,4': 'минус одну целую и четыре десятых',
#  '-1,5': 'минус одну целую и пять десятых',
#  '-1,5 кг.': 'минус одну целую и пять десятых килограмма',
#  '-1,5 м': 'минус одна целая и пять десятых метра',
#  '-1,5 м.': 'минус одна целая и пять десятых метра',
#  '-1,9%': 'минус одну целую и девять десятых процента',
#  '-1/2013': 'минус одна две тысячи тринадцатая',
#  '-10': 'минус десять',
#  '-10 b': 'минус десять миллиардов',
#  '-10 с': 'минус десять секунд',
#  '-10,0': 'минус десять',
#  '-10,0 м': 'минус десять метров',
#  '-100': 'минус сто',
#  '-100 м²': 'минус ста квадратными метрами',
#  '-101': 'минус сто один',
#  '-1011': 'минус тысяча одиннадцать',
#  '-101903': 'минус сто одна тысяча девятьсот три',
#  '-102': 'минус сто два',
#  '-1024': 'минус тысяча двадцать четыре',
#  '-1028': 'минус тысяча двадцать восемь',
#  '-103': 'минус сто три',
#  '-104': 'минус сто четыре',
#  '-104,105,106': 'минус один ноль четыре один ноль пять один ноль шесть',
#  '-105': 'минус сто пять',
#  '-106': 'минус сто шесть',
#  '-107': 'минус сто семь',
#  '-1078': 'минус тысяча семьдесят восемь',
#  '-108': 'минус один ноль восемь',
#  '-1083': 'минус тысяча восемьдесят три',
#  '-109': 'минус сто девять',
#  '-11': 'минус одиннадцать',
#  '-11,00': 'минус один один',
#  '-11,1 млрд': 'минус одиннадцать целых и одну десятую миллиарда',
#  '-110': 'минус сто десять',
#  '-1106': 'минус тысяча сто шесть',
#  '-111': 'минус сто одиннадцать',
#  '-11180': 'минус одиннадцать тысяч сто восемьдесят',
#  '-112': 'минус один один два',
#  '-113': 'минус один один три',
#  '-114': 'минус сто четырнадцать',
#  '-115': 'минус сто пятнадцать',
#  '-116': 'минус один один шесть',
#  '-116,117,118': 'минус один один шесть один один семь один один восемь',
#  '-1167': 'тысяча сто шестьдесят седьмом',
#  '-117': 'минус сто семнадцать',
#  '-118': 'минус сто восемнадцать',
#  '-119': 'минус сто девятнадцать',
#  '-119 с': 'минус сто девятнадцать секунд',
#  '-11А': 'минус одиннадцать ампер',
#  '-12': 'минус двенадцать',
#  '-12 b': 'минус двенадцать миллиардов',
#  '-12 с.': 'минус двенадцать секунд',
#  '-120': 'минус сто двадцать',
#  '-1202': 'тысяча двести второго',
#  '-120с.': 'минус сто двадцать секунд',
#  '-121': 'минус сто двадцать один',
#  '-122': 'минус сто двадцать две',
#  '-1226': 'минус тысяча двести двадцать шесть',
#  '-1227': 'минус тысяча двести двадцать семь',
#  '-123': 'минус сто двадцать три',
#  '-124': 'минус один два четыре',
#  '-1240 м': 'минус тысяча двести сорок метров',
#  '-125': 'минус сто двадцать пять',
#  '-125 с': 'минус сто двадцать пять секунд',
#  '-1251': 'минус тысяча двести пятьдесят один',
#  '-126': 'минус сто двадцать шесть',
#  '-1263': 'минус один два шесть три',
#  '-127': 'минус сто двадцать семь',
#  '-1272': 'тысяча двести семьдесят втором',
#  '-1275': 'минус тысяча двести семьдесят пять',
#  '-128': 'минус один два восемь',
#  '-1284': 'минус тысяча двести восемьдесят четыре',
#  '-129': 'минус сто двадцать девять',
#  '-12993': 'минус двенадцать тысяч девятьсот девяносто три',
#  '-13': 'минус тринадцать',
#  '-13 мм': 'минус тринадцать миллиметров',
#  '-13 с': 'минус тринадцать секунд',
#  '-13,5 кг': 'минус тринадцать целых и пять десятых килограмма',
#  '-13,5 км.': 'минус тринадцать целых и пять десятых километра',
#  '-130': 'минус сто тридцать',
#  '-1300': 'тысяча трехсотом',
#  '-131': 'минус один три один',
#  '-132': 'минус один три два',
#  '-1322': 'тысяча триста двадцать втором',
#  '-133': 'минус один три три',
#  '-1335': 'тысяча триста тридцать пятом',
#  '-134': 'минус один три четыре',
#  '-135': 'минус сто тридцать пять',
#  '-138': 'минус один три восемь',
#  '-139': 'минус сто тридцать девять',
#  '-1397': 'тысяча триста девяносто седьмом',
#  '-14': 'минус четырнадцать',
#  '-14 b': 'минус четырнадцать миллиардов',
#  '-14/13': 'минус четырнадцать тринадцатых',
#  '-140': 'минус один четыре ноль',
#  '-1400': 'минус тысяча четыреста',
#  '-1402': 'минус тысяча четыреста два',
#  '-1405': 'минус тысяча четыреста пять',
#  '-141': 'минус сто сорок один',
#  '-141, 319, 322': 'минус один четыре один три один девять три два два',
#  '-1417': 'минус тысяча четыреста семнадцать',
#  '-1419': 'тысяча четыреста девятнадцатом',
#  '-142': 'минус один четыре два',
#  '-14240': 'минус четырнадцать тысяч двести сорок',
#  '-143': 'минус один четыре три',
#  '-1430': 'тысяча четыреста тридцатом',
#  '-1439': 'минус тысяча четыреста тридцать девять',
#  '-144': 'минус один четыре четыре',
#  '-1447': 'тысяча четыреста сорок седьмом',
#  '-1460': 'минус тысяча четыреста шестьдесят',
#  '-148': 'минус сто сорок восемь',
#  '-15': 'минус пятнадцать',
#  '-15 с': 'минус пятнадцать секунд',
#  '-15,000': 'минус пятнадцати тысяч',
#  '-15,001': 'минус пятнадцать целых и одна тысячная',
#  '-15,599': 'минус пятнадцать целых и пятьсот девяносто девять тысячных',
#  '-150': 'минус сто пятьдесят',
#  '-150 тыс. т.': 'минус сто пятьдесят тысяч тонн',
#  '-15000': 'минус пятнадцать тысяч',
#  '-151': 'минус сто пятьдесят один',
#  '-1512': 'тысяча пятьсот двенадцатом',
#  '-1522': 'минус один пять два два',
#  '-1524': 'минус тысяча пятьсот двадцать четыре',
#  '-1536': 'тысяча пятьсот тридцать шестом',
#  '-1538': 'тысяча пятьсот тридцать восьмом',
#  '-1539': 'тысяча пятьсот тридцать девятом',
#  '-154': 'минус сто пятьдесят четыре',
#  '-155': 'минус сто пятьдесят пять',
#  '-1552': 'тысяча пятьсот пятьдесят втором',
#  '-156': 'минус сто пятьдесят шесть',
#  '-1572': 'минус тысяча пятьсот семьдесят два',
#  '-1582': 'тысяча пятьсот восемьдесят втором',
#  '-1586': 'тысяча пятьсот восемьдесят шестом',
#  '-1590': 'тысяча пятьсот девяностом',
#  '-16': 'минус шестнадцать',
#  '-16 с': 'минус шестнадцать секунд',
#  '-160': 'минус сто шестьдесят',
#  '-1600': 'тысяча шестисотом',
#  '-1611': 'тысяча шестьсот одиннадцатом',
#  '-1614': 'тысяча шестьсот четырнадцатом',
#  '-1617': 'тысяча шестьсот семнадцатом',
#  '-1618': 'тысяча шестьсот восемнадцатом',
#  '-162': 'минус сто шестьдесят два',
#  '-1629': 'тысяча шестьсот двадцать девятом',
#  '-163': 'минус сто шестьдесят три',
#  '-1635': 'тысяча шестьсот тридцать пятом',
#  '-1648': 'минус тысяча шестьсот сорок восемь',
#  '-1649': 'тысяча шестьсот сорок девятом',
#  '-165': 'минус сто шестьдесят пять',
#  '-1650': 'тысяча шестьсот пятидесятом',
#  '-1654': 'тысяча шестьсот пятьдесят четвертого',
#  '-1655': 'тысяча шестьсот пятьдесят пятом',
#  '-1657': 'тысяча шестьсот пятьдесят седьмом',
#  '-1659': 'тысяча шестьсот пятьдесят девятого',
#  '-166': 'минус сто шестьдесят шесть',
#  '-1661': 'тысяча шестьсот шестьдесят первом',
#  '-1672': 'тысяча шестьсот семьдесят втором',
#  '-1674': 'тысяча шестьсот семьдесят четвертом',
#  '-1676': 'тысяча шестьсот семьдесят шестом',
#  '-168 с.': 'минус сто шестьдесят восемь секунд',
#  '-1680': 'тысяча шестьсот восьмидесятом',
#  '-1684': 'тысяча шестьсот восемьдесят четвертом',
#  '-169': 'минус сто шестьдесят девять',
#  '-17': 'минус семнадцать',
#  '-1701': 'минус тысяча семьсот один',
#  '-1712': 'тысяча семьсот двенадцатом',
#  '-17144': 'минус семнадцать тысяч сто сорок четыре',
#  '-1716': 'тысяча семьсот шестнадцатом',
#  '-1723': 'минус тысяча семьсот двадцать три',
#  '-1724': 'тысяча семьсот двадцать четвертом',
#  '-1727': 'тысяча семьсот двадцать седьмом',
#  '-1729': 'минус тысяча семьсот двадцать девять',
#  '-1732': 'тысяча семьсот тридцать втором',
#  '-1739': 'тысяча семьсот тридцать девятом',
#  '-1741': 'тысяча семьсот сорок первом',
#  '-1744': 'минус тысяча семьсот сорок четыре',
#  '-1746': 'тысяча семьсот сорок шестом',
#  '-175': 'минус сто семьдесят пять',
#  '-1750': 'тысяча семьсот пятидесятом',
#  '-1757': 'тысяча семьсот пятьдесят седьмом',
#  '-1761': 'тысяча семьсот шестьдесят первом',
#  '-1762': 'минус тысяча семьсот шестьдесят два',
#  '-1763': 'тысяча семьсот шестьдесят третьем',
#  '-1764': 'тысяча семьсот шестьдесят четвертом',
#  '-1768': 'тысяча семьсот шестьдесят восьмом',
#  '-1770': 'тысяча семьсот семидесятом',
#  '-1773': 'тысяча семьсот семьдесят третьем',
#  '-1775': 'тысяча семьсот семьдесят пятом',
#  '-1778': 'тысяча семьсот семьдесят восьмом',
#  '-178': 'минус сто семьдесят восемь',
#  '-1780': 'тысяча семьсот восьмидесятом',
#  '-1782': 'тысяча семьсот восемьдесят втором',
#  '-1783': 'тысяча семьсот восемьдесят третьем',
#  '-1790': 'минус один семь девять ноль',
#  '-1793': 'тысяча семьсот девяносто третьем',
#  '-1795': 'тысяча семьсот девяносто пятом',
#  '-1798': 'тысяча семьсот девяносто восьмом',
#  '-1799': 'тысяча семьсот девяносто девятом',
#  '-18': 'минус восемнадцать',
#  '-18 b': 'минус восемнадцать миллиардов',
#  '-180': 'минус сто восемьдесят',
#  '-1800': 'тысяча восьмисотом',
#  '-1812': 'тысяча восемьсот двенадцатого',
#  '-1816': 'тысяча восемьсот шестнадцатом',
#  '-1822': 'тысяча восемьсот двадцать втором',
#  '-1824': 'тысяча восемьсот двадцать четвертого',
#  '-1826': 'тысяча восемьсот двадцать шестом',
#  '-1829': 'тысяча восемьсот двадцать девятом',
#  '-183,9': 'минус сто восемьдесят три целых и девять десятых',
#  '-1831': 'тысяча восемьсот тридцать первом',
#  '-1841': 'тысяча восемьсот сорок первом',
#  '-1843': 'тысяча восемьсот сорок третьем',
#  '-1847': 'тысяча восемьсот сорок седьмом',
#  '-184б.': 'минус сто восемьдесят четыре байта',
#  '-185 с.': 'минус сто восемьдесят пять секунд',
#  '-1851': 'тысяча восемьсот пятьдесят первом',
#  '-1852': 'тысяча восемьсот пятьдесят втором',
#  '-1855': 'тысяча восемьсот пятьдесят пятом',
#  '-1856': 'тысяча восемьсот пятьдесят шестом',
#  '-1861': 'тысяча восемьсот шестьдесят первом',
#  '-1862': 'тысяча восемьсот шестьдесят втором',
#  '-1863': 'тысяча восемьсот шестьдесят третьем',
#  '-1865': 'тысяча восемьсот шестьдесят пятом',
#  '-1866': 'минус тысяча восемьсот шестьдесят шесть',
#  '-1867': 'тысяча восемьсот шестьдесят седьмого',
#  '-187': 'минус сто восемьдесят семь',
#  '-1870': 'тысяча восемьсот семидесятом',
#  '-1873': 'тысяча восемьсот семьдесят третьем',
#  '-1874': 'тысяча восемьсот семьдесят четвертом',
#  '-1875': 'минус тысяча восемьсот семьдесят пять',
#  '-1876': 'тысяча восемьсот семьдесят шестом',
#  '-1878': 'тысяча восемьсот семьдесят восьмом',
#  '-1880': 'тысяча восемьсот восьмидесятом',
#  '-1883': 'тысяча восемьсот восемьдесят третьем',
#  '-1886': 'тысяча восемьсот восемьдесят шестом',
#  '-1887': 'тысяча восемьсот восемьдесят седьмом',
#  '-1888': 'тысяча восемьсот восемьдесят восьмом',
#  '-189,9': 'минус сто восемьдесят девять целых и девять десятых',
#  '-1890': 'тысяча восемьсот девяностом',
#  '-1892': 'тысяча восемьсот девяносто втором',
#  '-1893': 'тысяча восемьсот девяносто третьем',
#  '-1894': 'тысяча восемьсот девяносто четвертом',
#  '-1895': 'тысяча восемьсот девяносто пятом',
#  '-1896': 'тысяча восемьсот девяносто шестом',
#  '-1897': 'минус тысяча восемьсот девяносто семь',
#  '-1898': 'тысяча восемьсот девяносто восьмом',
#  '-19': 'минус девятнадцать',
#  '-19,5 см': 'минус девятнадцать целых и пять десятых сантиметра',
#  '-190': 'минус сто девяносто',
#  '-1903': 'тысяча девятьсот третьем',
#  '-1905': 'тысяча девятьсот пятом',
#  '-1906': 'тысяча девятьсот шестом',
#  '-1907': 'тысяча девятьсот седьмом',
#  '-1908': 'тысяча девятьсот восьмом',
#  '-1909': 'тысяча девятьсот девятом',
#  '-191': 'минус ста девяноста одной',
#  '-1910': 'тысяча девятьсот десятом',
#  '-19100': 'минус девятнадцать тысяч сто',
#  '-1912': 'тысяча девятьсот двенадцатом',
#  '-1913': 'тысяча девятьсот тринадцатом',
#  '-1915': 'тысяча девятьсот пятнадцатом',
#  '-1916': 'минус тысяча девятьсот шестнадцать',
#  '-1917': 'тысяча девятьсот семнадцатом',
#  '-1918': 'тысяча девятьсот восемнадцатом',
#  '-1919': 'тысяча девятьсот девятнадцатом',
#  '-192': 'минус сто девяносто два',
#  '-1920': 'тысяча девятьсот двадцатом',
#  '-1921': 'тысяча девятьсот двадцать первом',
#  '-1922': 'тысяча девятьсот двадцать втором',
#  '-1923': 'тысяча девятьсот двадцать третьем',
#  '-1924': 'тысяча девятьсот двадцать четвертом',
#  '-1925': 'тысяча девятьсот двадцать пятом',
#  '-1926': 'тысяча девятьсот двадцать шестом',
#  '-1927': 'тысяча девятьсот двадцать седьмом',
#  '-1928': 'тысяча девятьсот двадцать восьмом',
#  '-1929': 'тысяча девятьсот двадцать девятом',
#  '-1930': 'тысяча девятьсот тридцатом',
#  '-1931': 'тысяча девятьсот тридцать первом',
#  '-1932': 'тысяча девятьсот тридцать втором',
#  '-1933': 'тысяча девятьсот тридцать третьем',
#  '-1935': 'тысяча девятьсот тридцать пятом',
#  '-1936': 'тысяча девятьсот тридцать шестом',
#  '-1937': 'тысяча девятьсот тридцать седьмом',
#  '-1938': 'тысяча девятьсот тридцать восьмом',
#  '-1939': 'тысяча девятьсот тридцать девятом',
#  '-1940': 'тысяча девятьсот сороковом',
#  '-1941': 'тысяча девятьсот сорок первом',
#  '-1942': 'тысяча девятьсот сорок втором',
#  '-1943': 'тысяча девятьсот сорок третьем',
#  '-1944': 'тысяча девятьсот сорок четвертом',
#  '-1945': 'тысяча девятьсот сорок пятом',
#  '-1946': 'тысяча девятьсот сорок шестом',
#  '-1947': 'тысяча девятьсот сорок седьмом',
#  '-1949': 'тысяча девятьсот сорок девятом',
#  '-1950': 'тысяча девятьсот пятидесятом',
#  '-1951': 'тысяча девятьсот пятьдесят первом',
#  '-1952': 'тысяча девятьсот пятьдесят втором',
#  '-1953': 'тысяча девятьсот пятьдесят третьем',
#  '-1954': 'тысяча девятьсот пятьдесят четвертом',
#  '-1955': 'тысяча девятьсот пятьдесят пятом',
#  '-1956': 'тысяча девятьсот пятьдесят шестом',
#  '-1957': 'тысяча девятьсот пятьдесят седьмом',
#  '-1958': 'тысяча девятьсот пятьдесят восьмом',
#  '-1959': 'минус тысяча девятьсот пятьдесят девять',
#  '-196': 'минус сто девяносто шесть',
#  '-1960': 'тысяча девятьсот шестидесятом',
#  '-1961': 'тысяча девятьсот шестьдесят первом',
#  '-1962': 'тысяча девятьсот шестьдесят втором',
#  '-1963': 'тысяча девятьсот шестьдесят третьем',
#  '-1964': 'тысяча девятьсот шестьдесят четвертом',
#  '-1965': 'тысяча девятьсот шестьдесят пятом',
#  '-1966': 'тысяча девятьсот шестьдесят шестом',
#  '-1967': 'тысяча девятьсот шестьдесят седьмом',
#  '-1968': 'тысяча девятьсот шестьдесят восьмом',
#  '-1969': 'тысяча девятьсот шестьдесят девятом',
#  '-1970': 'тысяча девятьсот семидесятом',
#  '-1971': 'тысяча девятьсот семьдесят первом',
#  '-1972': 'тысяча девятьсот семьдесят втором',
#  '-1973': 'тысяча девятьсот семьдесят третьем',
#  '-1974': 'тысяча девятьсот семьдесят четвертом',
#  '-1975': 'тысяча девятьсот семьдесят пятом',
#  '-1976': 'тысяча девятьсот семьдесят шестом',
#  '-1977': 'минус один девять семь семь',
#  '-1978': 'тысяча девятьсот семьдесят восьмом',
#  '-1979': 'тысяча девятьсот семьдесят девятом',
#  '-1980': 'тысяча девятьсот восьмидесятом',
#  '-1981': 'тысяча девятьсот восемьдесят первом',
#  '-1982': 'тысяча девятьсот восемьдесят втором',
#  '-1983': 'тысяча девятьсот восемьдесят третьем',
#  '-1984': 'тысяча девятьсот восемьдесят четвертом',
#  '-1985': 'тысяча девятьсот восемьдесят пятом',
#  '-1986': 'тысяча девятьсот восемьдесят шестом',
#  '-1987': 'тысяча девятьсот восемьдесят седьмом',
#  '-1988': 'тысяча девятьсот восемьдесят восьмом',
#  '-1989': 'тысяча девятьсот восемьдесят девятом',
#  '-199': 'минус сто девяносто девять',
#  '-1990': 'тысяча девятьсот девяностом',
#  '-1991': 'тысяча девятьсот девяносто первом',
#  '-1992': 'тысяча девятьсот девяносто втором',
#  '-1993': 'минус тысяча девятьсот девяносто три',
#  '-1994': 'тысяча девятьсот девяносто четвертом',
#  '-1995': 'тысяча девятьсот девяносто пятом',
#  '-1996': 'тысяча девятьсот девяносто шестом',
#  '-1997': 'тысяча девятьсот девяносто седьмом',
#  '-1998': 'тысяча девятьсот девяносто восьмом',
#  '-1999': 'тысяча девятьсот девяносто девятом',
#  '-19b': 'минус девятнадцать миллиардов',
#  '-1b': 'минус один миллиард',
#  '-1В.': 'минус один вольт',
#  '-1см.': 'минус один сантиметр',
#  '-2': 'минус два',
#  '-2 %': 'минус два процента',
#  '-2 километрах': 'минус двух километрах',
#  '-2 км': 'минус два километра',
#  '-2 км.': 'минус два километра',
#  '-2 м': 'минус два метра',
#  '-2 метра.': 'минус два метра',
#  '-2 см': 'минус два сантиметра',
#  '-2,2 мм.': 'минус две целых и две десятых миллиметра',
#  '-2,33': 'минус две целых и тридцать три сотых',
#  '-2,5': 'минус двух целых и пяти десятых',
#  '-2,5 км.': 'минус две целых и пять десятых километра',
#  '-2,5 мм': 'минус две целых и пять десятых миллиметра',
#  '-2,6 м.': 'минус две целых и шесть десятых метра',
#  '-2,6 мм.': 'минус две целых и шесть десятых миллиметра',
#  '-2,7 ГГц.': 'минус две целых и семь десятых гигагерца',
#  '-2,8': 'минус две целых и восемь десятых',
#  '-2,8 км.': 'минус две целых и восемь десятых километра',
#  '-20': 'минус двадцать',
#  '-20,000': 'минус двадцать тысяч',
#  '-20,7 см': 'минус двадцати целых и семи десятых сантиметра',
#  '-200': 'минус двести',
#  '-2000': 'минус две тысячи',
#  '-2000 пиксели': 'минус две тысячи пиксели',
#  '-2001': 'две тысячи первом',
#  '-2002': 'две тысячи втором',
#  '-2003': 'минус две тысячи три',
#  '-2004': 'две тысячи четвертом',
#  '-2005': 'две тысячи пятом',
#  '-2006': 'две тысячи шестом',
#  '-20060125': 'минус двадцать миллионов шестьдесят тысяч сто двадцать пять',
#  '-2007': 'минус две тысячи семь',
#  '-2008': 'две тысячи восьмом',
#  '-2009': 'две тысячи девятом',
#  '-200с.': 'минус двести секунд',
#  '-201': 'минус два ноль один',
#  '-2010': 'две тысячи десятом',
#  '-2011': 'две тысячи одиннадцатом',
#  '-2012': 'две тысячи двенадцатом',
#  '-20120626': 'минус два ноль один два ноль шесть два шесть',
#  '-2013': 'две тысячи тринадцатом',
#  '-2014': 'две тысячи четырнадцатом',
#  '-2015': 'две тысячи пятнадцатом',
#  '-2016': 'две тысячи шестнадцатом',
#  '-2017': 'две тысячи семнадцатом',
#  '-2020': 'две тысячи двадцатом',
#  '-2026': 'две тысячи двадцать шестом',
#  '-203': 'минус двести три',
#  '-2030': 'минус две тысячи тридцать',
#  '-205': 'минус двести пять',
#  '-206': 'минус двести шесть',
#  '-2071': 'минус две тысячи семьдесят один',
#  '-208': 'минус двести восемь',
#  '-2081': 'минус две тысячи восемьдесят один',
#  '-2082': 'минус две тысячи восемьдесят два',
#  '-2083': 'минус две тысячи восемьдесят три',
#  '-2085 с': 'минус две тысячи восемьдесят пять секунд',
#  '-2089': 'минус две тысячи восемьдесят девять',
#  '-209': 'минус двести девять',
#  '-21': 'минус двадцать один',
#  '-21,1 %': 'минус двадцать одна целая и одна десятая процента',
#  '-210': 'минус двести десять',
#  '-211': 'минус двести одиннадцать',
#  '-212': 'минус двести двенадцать',
#  '-214': 'минус двести четырнадцать',
#  '-215': 'минус двести пятнадцать',
#  '-2167': 'минус две тысячи сто шестьдесят семь',
#  '-21782': 'минус двадцать одна тысяча семьсот восемьдесят два',
#  '-218': 'минус двести восемнадцать',
#  '-22': 'минус двадцать два',
#  '-22 с': 'минус двадцать две секунды',
#  '-220': 'минус двести двадцать',
#  '-2214': 'минус две тысячи двести четырнадцать',
#  '-222, 270, 277': 'минус два два два два семь ноль два семь семь',
#  '-223': 'минус двести двадцать три',
#  '-2238': 'минус две тысячи двести тридцать восемь',
#  '-225': 'минус двести двадцать пять',
#  '-226': 'минус двести двадцать шесть',
#  '-227': 'минус двести двадцать семь',
#  '-2298': 'минус две тысячи двести девяносто восемь',
#  '-23': 'минус двадцать три',
#  '-23,500': 'минус двадцать три целых и пятьсот тысячных',
#  '-23/14': 'минус двадцать три четырнадцатых',
#  '-230': 'минус двести тридцать',
#  '-232': 'минус двести тридцать два',
#  '-2337': 'минус две тысячи триста тридцать семь',
#  '-234': 'минус двести тридцать четыре',
#  '-235': 'минус двести тридцать пять',
#  '-237': 'минус двести тридцать семь',
#  '-24': 'минус двадцать четыре',
#  '-240': 'минус двести сорок',
#  '-2400': 'минус две тысячи четыреста',
#  '-240с.': 'минус двести сорок секунд',
#  '-242': 'минус двести сорок два',
#  '-243': 'минус двести сорок три',
#  '-249': 'минус двести сорок девять',
#  '-2491876': 'минус два миллиона четыреста девяносто одна тысяча восемьсот семьдесят шесть',
#  '-25': 'минус двадцать пять',
#  '-250': 'минус двести пятьдесят',
#  '-253': 'минус двести пятьдесят три',
#  '-253,267': 'минус двести пятьдесят три целых и двести шестьдесят семь тысячных',
#  '-254': 'минус двести пятьдесят четыре',
#  '-2540': 'минус две тысячи пятьсот сорок',
#  '-255': 'минус двести пятьдесят пять',
#  '-256': 'минус двести пятьдесят шесть',
#  '-26': 'двадцать шестом',
#  '-260': 'минус двести шестьдесят',
#  '-261': 'двести шестьдесят первом',
#  '-263': 'минус двести шестьдесят три',
#  '-2630': 'минус две тысячи шестьсот тридцать',
#  '-26431': 'минус два шесть четыре три один',
#  '-2664': 'минус две тысячи шестьсот шестьдесят четыре',
#  '-267': 'минус двести шестьдесят семь',
#  '-2670': 'минус две тысячи шестьсот семьдесят',
#  '-2688': 'минус две тысячи шестьсот восемьдесят восемь',
#  '-269,275': 'минус двести шестьдесят девять целых и двести семьдесят пять тысячных',
#  '-27': 'минус двадцать семь',
#  '-27 с': 'минус двадцать семь секунд',
#  '-2704': 'минус две тысячи семьсот четыре',
#  '-2714': 'минус две тысячи семьсот четырнадцать',
#  '-272': 'минус двести семьдесят два',
#  '-276,289': 'минус двести семьдесят шесть целых и двести восемьдесят девять тысячных',
#  '-277 с.': 'минус двести семьдесят семь секунд',
#  '-278': 'минус двести семьдесят восемь',
#  '-28': 'минус двадцать восемь',
#  '-280': 'минус двести восемьдесят',
#  '-28032': 'минус двадцать восемь тысяч тридцать два',
#  '-283 с.': 'минус двести восемьдесят три секунды',
#  '-285': 'минус двести восемьдесят пять',
#  '-289': 'минус двести восемьдесят девять',
#  '-29': 'минус двадцать девять',
#  '-29 с': 'минус двадцать девять секунд',
#  '-291': 'минус двести девяносто один',
#  '-294 с.': 'минус двести девяносто четыре секунды',
#  '-297': 'минус двести девяносто семь',
#  '-3': 'минус три',
#  '-3 b': 'минус три миллиарда',
#  '-3 км': 'минус три километра',
#  '-3 м': 'минус три метра',
#  '-3 метра': 'минус три метра',
#  '-3 мм.': 'минус три миллиметра',
#  '-3 недели.': 'минус три недели',
#  '-3 с': 'минус три секунды',
#  '-3 см': 'минус три сантиметра',
#  '-3 тысячи': 'минус три тысячи',
#  '-3,0 %': 'минус три процента',
#  '-3,0 мг': 'минус трех миллиграмм',
#  '-3,1 мкг': 'минус три целых и одна десятая микрограмма',
#  '-3,1 млрд': 'минус три целых и одна десятая миллиарда',
#  '-3,7 метра.': 'минус три целых и семь десятых метра',
#  '-3,7 мм': 'минус три целых и семь десятых миллиметра',
#  '-30': 'минус тридцать',
#  '-30 с': 'минус тридцать секунд',
#  '-300': 'минус триста',
#  '-303': 'минус триста три',
#  '-305': 'минус триста пять',
#  '-308': 'минус триста восемь',
#  '-309, 430, 542': 'минус три ноль девять четыре три ноль пять четыре два',
#  '-31': 'минус тридцать один',
#  '-31 b': 'минус тридцать один миллиард',
#  '-310и': 'минус трехстах десяти',
#  '-314': 'минус триста четырнадцать',
#  '-314 b': 'минус триста четырнадцать миллиардов',
#  '-319 с.': 'минус триста девятнадцать секунд',
#  '-32': 'минус тридцать два',
#  '-32 b': 'минус тридцать два миллиарда',
#  '-320': 'минус триста двадцать',
#  '-32009': 'минус тридцать две тысячи девять',
#  '-323': 'минус три два три',
#  '-32b': 'минус тридцать два миллиарда',
#  '-33': 'минус тридцать три',
#  '-330': 'минус триста тридцать',
#  '-335': 'минус триста тридцать пять',
#  '-338': 'минус триста тридцать восемь',
#  '-34': 'минус тридцать четыре',
#  '-340': 'минус триста сорок',
#  '-341': 'минус триста сорок один',
#  '-346': 'минус триста сорок шесть',
#  '-347': 'минус триста сорок семь',
#  '-35': 'минус три пять',
#  '-35 с': 'минус тридцать пять секунд',
#  '-35,000': 'минус тридцать пять тысяч',
#  '-356с.': 'минус триста пятьдесят шесть секунд',
#  '-36': 'минус три шесть',
#  '-362': 'минус триста шестьдесят два',
#  '-365': 'минус триста шестьдесят пять',
#  '-367': 'минус триста шестьдесят семь',
#  '-368 с.': 'минус триста шестьдесят восемь секунд',
#  '-37': 'минус три семь',
#  '-37 b': 'минус тридцать семь миллиардов',
#  '-37 с.': 'минус тридцать семь секунд',
#  '-37005': 'минус тридцать семь тысяч пять',
#  '-3701876': 'минус три миллиона семьсот одна тысяча восемьсот семьдесят шесть',
#  '-372': 'минус триста семьдесят два',
#  '-373': 'минус триста семьдесят три',
#  '-374': 'минус триста семьдесят четыре',
#  '-3754': 'минус три тысячи семьсот пятьдесят четыре',
#  '-3784': 'минус три тысячи семьсот восемьдесят четыре',
#  '-37b': 'минус тридцать семь миллиардов',
#  '-38': 'минус три восемь',
#  '-38 (А)': 'минус тридцать восемь ампер',
#  '-38 (Б)': 'минус тридцать восемь байтов',
#  '-38 (В)': 'минус тридцать восемь вольт',
#  '-382 с.': 'минус триста восемьдесят две секунды',
#  '-384': 'минус триста восемьдесят четыре',
#  '-384 с.': 'минус триста восемьдесят четыре секунды',
#  ...}

# %%
sub = pd.read_csv(DATA_DIR + 'ru_test.csv')

# %%
sub['after'] = sub.before.replace(trans_dict)

# %% [markdown]
# ### Model Attributes
# *  Ignores: local context, POS tags, n-grams, general rules
# *  Requires large training set

# %% [markdown]
# ### Further Directions
# *  Foreign Words & Transliteration
# *  Acronyms
# *  Tree-based models using POS and local context
